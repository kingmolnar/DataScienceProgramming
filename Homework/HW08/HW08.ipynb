# %% [markdown]
# # Homework 8

# %% [markdown]
# ## 8.1 Data Exploration
#
# Review Chapter 3 "Data Exploration"
# of the [Fundamentals of Machine Learning for Predictive Data Analytics](https://mitpress.mit.edu/9780262044691/fundamentals-of-machine-learning-for-predictive-data-analytics/) book.

# %% [markdown]
# Ananalytics consultant at an insurance company has built an ABT that will be used to train a model to predict the best communications channel to use to contact a potential customer with an offer of a new insurance product. The following table contains an extract from this ABT — the full ABT contains 5,200 instances.
#
# ![image.png](attachment:30eab68b-74b2-41a9-a0e4-05e5541c6801.png)
#
# The descriptive features in this dataset are defined as follows:
# - AGE: The customer’s age
# - GENDER: The customer’s gender (male or female)
# - LOC: The customer’s location (rural or urban)
# - OCC: The customer’s occupation
# - MOTORINS: Whether the customer holds a motor insurance policy with the com- pany (yes or no)
# - MOTORVALUE: The value of the car on the motor policy
# - HEALTHINS: Whether the customer holds a health insurance policy with the company (yes or no)
# - HEALTHTYPE: The type of the health insurance policy (PlanA, PlanB, or PlanC)
# - HEALTHDEPSADULTS: How many dependent adults are included on the health insurance policy
# - HEALTHDEPSKIDS: How many dependent children are included on the health insurance policy
# - PREFCHANNEL: The customer’s preferred contact channel (email, phone, or sms)
#
# The consultant generated the following **data quality report** from the ABT (visualizations of binary features have been omitted for space saving).
#
# ![image.png](attachment:1e35153c-bc99-4f38-a889-9856ca008c84.png)
#
# ![image.png](attachment:a33904f4-c163-44bc-acec-3754196aa4de.png)

# %% [markdown]
# #### Instructions 8.1
#
# Discuss this data quality report in terms of the following:
# 1. Missing values
# 2. Irregular cardinality
# 3. Outliers
# 4. Feature distributions
#
# Save your solution to `answer_8_1.txt`

# %%
# %%writefile answer_8_1.txt
# ## Write regular text. Ignore the Python syntax highlighting.
# ## Lines that start with '#' will be considered comments and ignored.

# %% [markdown]
# ## 8.2 Information-Based Learning
#
# Review Chapter 4 "Information-Based Learning"
# of the [Fundamentals of Machine Learning for Predictive Data Analytics](https://mitpress.mit.edu/9780262044691/fundamentals-of-machine-learning-for-predictive-data-analytics/) book.

# %% [markdown]
# The image below shows a set of eight Scrabble pieces.
#
# ![image.png](attachment:d0812bb9-1203-40ad-ac25-6a797394226f.png)

# %% [markdown]
# #### Instructions 8.2
#
# Anser the following questions:
# 1. What is the **entropy** in bits of the letters in this set?
# 2. What would be the reduction in entropy (i.e., the **information gain**)  in bits if we split these letters into two sets, one containing the vowels and the other containing the consonants?
# 3. What is the maximum possible entropy in bits for a set of eight Scrabble pieces?
# 4. In general, which is preferable when you are playing Scrabble: a set of letters with high entropy or a set of letters with low entropy?
#
# Save your answers to `answer_8_2.txt`

# %%
# %%writefile answer_8_2.txt

# %% [markdown]
# ## 8.3 Information-Based Learning
#
# Review Chapter 4 "Information-Based Learning"
# of the [Fundamentals of Machine Learning for Predictive Data Analytics](https://mitpress.mit.edu/9780262044691/fundamentals-of-machine-learning-for-predictive-data-analytics/) book.

# %% [markdown]
# A convicted criminal who reoffends after release is known as a *recidivist*.
# The following table lists a dataset that describes prisoners released on parole and whether they reoffended within two years of release.
#
# ![image.png](attachment:f6879d7a-3413-42bd-b2ef-b6d6ed78c9ee.png)
#
# This dataset lists six instances in which prisoners were granted parole. Each of these instances is described in terms of three binary descriptive features (`GOOD BEHAV- IOR`, `AGE < 30`, `DRUG DEPENDENT`) and a binary target feature (`RECIDIVIST`). The `GOOD BEHAVIOR` feature has a value of true if the prisoner had not committed any infringements during incarceration, the `AGE < 30` has a value of true if the prisoner was under 30 years of age when granted parole, and the `DRUG DEPENDENT` feature is true if the prisoner had a drug addiction at the time of parole. The target feature, `RECIDIVIST`, has a *true* value if the prisoner was arrested within two years of being released; otherwise it has a value of *false*.

# %% [markdown]
# ### Instructions 8.3
# Using this dataset, construct the decision tree that would be generated by the ID3 algorithm, using entropy-based information gain.
#
# Write the desicion tree in **Python-like** syntax.
#
# #### Example
# The decision tree
#
# ![image.png](attachment:78ca69a3-6074-45ad-a8a5-956cef30c2aa.png)
#
# would translate to:
# ```
# if CHEST_PAIN:
#     return True
# else:
#     if BLOOD_PRESSURE == 'high':
#         return True
#     else:
#         return False
# ```

# %% [markdown]
# Save your answers to `answer_8_3.txt`

# %%
# %%writefile answer_8_3.txt

# %% [markdown]
# ## 8.4 Error-Based Learning
#
# Review Chapter 7 "Error-Based Learning"
# of the [Fundamentals of Machine Learning for Predictive Data Analytics](https://mitpress.mit.edu/9780262044691/fundamentals-of-machine-learning-for-predictive-data-analytics/) book.

# %% [markdown]
# A multivariate linear regression model has been built to predict the heating load in a residential building on the basis of a set of descriptive features describing the characteristics of the building. Heating load is the amount of heat energy required to keep a building at a specified temperature, usually 65 degrees Fahrenheit during the winter regardless of outside temperature. The descriptive features used are the overall surface area of the building, the height of the building, the area of the building’s roof, and the per- centage of wall area in the building that is glazed. This kind of model would be useful to architects or engineers when designing a new building. The trained model is
#
# ![image.png](attachment:21834b2e-a323-40f6-9b01-2c685194523a.png)

# %% [markdown]
# #### Instructions 8.4
#
# Use this model to make predictions for each of the query instances shown in the following table.
#
# ![image.png](attachment:e352e555-199b-4c24-bab5-62d220bb5d8c.png)
#
# Save your answers to `answer_8_4.txt`.

# %%
# %%writefile answer_8_4.txt
# ## complete the table with the values for ID and predicted HEATING LOAD
# ID, HEATING_LOAD

# %% [markdown]
# ## 8.5 Evaluation
#
# Review Chapter 9 "Evaluation"
# of the [Fundamentals of Machine Learning for Predictive Data Analytics](https://mitpress.mit.edu/9780262044691/fundamentals-of-machine-learning-for-predictive-data-analytics/) book.

# %% [markdown]
# The table below shows the predictions made for a categorical target feature by a model for a test dataset. Based on this test set, calculate the evaluation measures listed below.
#
# ![image.png](attachment:5a7173a2-1d87-4de9-85d8-6449eab38710.png)

# %% [markdown]
# #### Instructions 8.5
#
# Calulate the following performance metrics for this test set:
# 1. misclassification rate
# 2. precision
# 3. recall
# 4. F1 measure

# %% [markdown]
# Save your answers to `answer_8_5.txt`

# %%
# %%writefile answer_8_5.txt

# %% [markdown]
# # Testing
#
# **Note:**
# - **These tests only check whether your answer files exist.**
# - **They do not check the correctness of your response.**

# %%
! ./test/run_test.sh

# %% [markdown]
# # Homework Submission
# - This homework is due by 2023-11-15, 5:30PM (EDT)
# - Make sure that all your programs and output files are in the exact folder as specified in the instructions.
# - All file names on this system are case sensitive. Verify if you copy your work from a local computer to your home directory on ARC.
# - No further action is need to submit your assignment.
